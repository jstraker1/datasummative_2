# %% [markdown]
# To do:
#
# - [ ] Test H3. Analyse how lifestyle factors influence medical risk markers - Use scatter plots and multiple linear regressions to see how lifestyle behaviours relate to BMI, blood pressure, cholesterol, glucose, and other medical variables. Lifestyle behaviours are the predictor and the medical risk factors are the dependent variables.
#
# - [ ] Test H4. Identify which medical risk factors predict each disease - Fit linear regressions that include medical markers to build richer models and compare these to the lifestyle only models. Similarly, the disease is the predictor, and the medical risk factor is the dependent variable. Also use scatter plots for further analysis.
#
# - [ ] Discuss limitations and validity - Address synthetic data issues, cross sectional design, model assumptions, and the educational nature of the tool.

# %% [markdown]
# Coding-wise:
#
# - [ ] Test H3 (with lifestyle behaviours as predictors and medical risk factors as dependent variables):
#     * [ ] calculate correlation coefficients (Pearson/Spearman) between lifestyle variables and medical risk factors to identify potentially strong relationships
#     * [ ] BMI scatter plot
#     * [ ] BMI linear/logistic regression
#     * [ ] blood pressure scatter plot
#     * [ ] blood pressure linear/logistic regression
#     * [ ] cholesterol scatter plot
#     * [ ] cholesterol linear/logistic regression
#     * [ ] glucose scatter plot
#     * [ ] glucose linear/logistic regression
#     * [ ] triglycerides scatter plot
#     * [ ] triglycerides linear/logistic regression
#     * [ ] HbA1c scatter plot
#     * [ ] HbA1c linear/logistic regression
#     * [ ] oxygen saturation scatter plot
#     * [ ] oxygen saturation linear/logistic regression
#     * [ ] multivariate models with multiple lifestyle factors included as predictors to see how they jointly affect medical risk markers
#
# - [ ] Test H4 (which medical risk factors - dependent variable - predict disease - predictor):
#     * [ ] logistic regression/classifier of medical markers vs lifestyle only models
#     * [ ] scatter plots for further analysis

# %% [markdown]
# discarded code:
